# %% [markdown]
# #### Profesor: Alexander Acevedo Gomez
# #### Grado: Noveno
# #### Asignatura: Emprendimiento

# %% [markdown]
# # Plan de Trabajo Grado Noveno - Emprendimiento

# %% [markdown]
# ## Instrucciones

# %% [markdown]
# Realice el plan de trabajo con los siguientes parametros para poder obtener los 4 puntos de su valor:
#
# 1. Copie los cuatro ambitos conceptuales
# 2. Copie las cuatro competencias segun el periodo que se inicia
# 3. Por cada compentencia escriba 3 pasos como minimo
# 4. Escriba los recursos que considera va emplear para alcanzar las competencias, minimo 4 recursos generales
# 5. Asigne las fechas indicadas por el profesor en clase.

# %% [markdown]
# | AMBITO CONCEPTUAL                     |     COMPETENCIAS                                  |     FECHAS                                                                   |     PASOS   PARA ALCANZAR LA COMPETENCIA                        |     RECURSOS                                     |     AUTOEVALUACION   Y FIRMA PROFESOR    |
# |---------------------------------------|---------------------------------------------------|------------------------------------------------------------------------------|-----------------------------------------------------------------|--------------------------------------------------|------------------------------------------|
# | Copie los cuatro ambitos conceptuales |         Copie las cuatro competencias del periodo |                                 Escriba las fechas indicadas por el profesor |         Escriba minimo 3 pasos por cada una de las competencias |         Escriba 4 recursos generales como minimo |         Deje vacío este espacio          |

# %% [markdown]
# | Periodo | Ambito Conceptual                                                                                              | Competencia                                                                                                                                                                                                     |
# |---------|----------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 1       | El emprendimiento tecnológico : concepto, características y aplicaciones en la vida cotidiana.                 | Comprende las características diferenciadoras del emprendimiento tecnológico para identificar problemas del entorno y proponer ideas de emprendimiento que puedan ser abordadas mediante este enfoque           |
# | 1       | Herramientas digitales básicas para el desarrollo del emprendimiento tecnológico                               | Reconoce las principales herramientas que puede emplear para materializar las diferentes etapas de un proyecto de emprendimiento tecnológico.                                                                   |
# | 1       | Toma de decisiones en el emprendimiento: identificación progresiva de oportunidades, riesgos y uso de recursos | Analiza, de acuerdo con su nivel de conocimiento, las oportunidades, riesgos y el uso de recursos de un emprendimiento para tomar decisiones responsables y argumentadas.                                       |
# | 1       | Disposición actitudinal y socioemocional                                                                       | Manifiesta su compromiso frente a su proyecto de vida a través de su puntualidad y cumplimiento de sus deberes académicos, sus actitudes reflejan un comportamiento socioemocional esperado y acorde a su edad. |

# %% [markdown]
# ## Ejemplos presentacion de plan de trabajo

# %% [markdown]
# - Opcion 1 : Lo puedes realizar todo en una sola tabla.
# - Opcion 2: Puedes devidirlo en dos tablas, asi:

# %% [markdown]
# ![image.png](image.png)
