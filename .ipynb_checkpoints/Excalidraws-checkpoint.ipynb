# %% [markdown]
# # Digramas para realizar en clase en el cuaderno

# %% [markdown]
# ## Clasificación de las herramientas tecnológicas

# %% [markdown]
# 1. Realiza en tu cuaderno el siguiente diagrama (sello de 4 puntos)

# %% [markdown]
# > [Haz clic para abrir el diagrama](https://excalidraw.com/#json=H1uf8g-hUE0MOS1_A0P14,l3rvNrawcixwFGAUKeg6gA)

# %% [markdown]
# ## Estructura de la programación por bloques

# %% [markdown]
# ![bloques](bloques.png)

# %% [markdown]
# ## Componentes de Scratch

# %% [markdown]
# ![scratch](scratch.png)

# %% [markdown]
# ## Informes financieros

# %% [markdown]
# ![informes-financieros](financieros.png)

# %% [markdown]
# ## Excel en los estados financieros

# %% [markdown]
# ![financiera](financiera.png)

# %% [markdown]
# ## Factura en Colombia

# %% [markdown]
# ![factura](factura.png)

# %% [markdown]
# ## Graficos para emprendimientos financieros

# %% [markdown]
# ![graficos](graficos.png)
