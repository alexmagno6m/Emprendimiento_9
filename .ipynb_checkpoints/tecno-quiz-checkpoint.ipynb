# %% [markdown]
# - __Diseñada por__: Alexander Acevedo Gómez
# - Docente de Informática y Programación
# - Ingeniero de sistemas
# - Magister en Modelado y Simulación por computador

# %% [markdown]
# ## Tecno-Quiz de competencias

# %% [markdown]
# ### Conocimientos previos de emprendimiento

# %% [markdown]
# Vamos a saber que tanto has aprendido de Emprendimiento, la idea es competir, a veces la suerte tambien cuenta!. Entre mas rápido contestes y aciertes mas puntos por pregunta obtienes.

# %% [markdown]
# > El tecno-quiz no hace que pierdas la materia, pero si te puede ayudar a aprobarla!

# %% [markdown]
# ### Quiz 1

# %% [markdown]
# Emplearemos la plataforma __Mentimeter__ para responder una serie de preguntas.

# %% [markdown]
# > ### Instrucciones
# >
# > - La competencia consta de varias preguntas de opción multiple con una sola respuesta correcta.
# > - Las preguntas tienen un tiempo máximo para que respondas, usualmente 7 u 8 segundos, si respondes fuera del tiempo, tu respuesta no será tenida en cuenta :(
# > - Ganarás mas puntos si respondes correctamente y lo haces en menos tiempo que los demás.
# > - Los primeros cinco lugares obtendrán 5 puntos, los siguientes cinco 4, los otros cinco 3 y asi sucesivamente.

# %% [markdown]
# > ### Ingresa al Quiz!
# >
# > 1. Ingresa a la página: [mentimeter.com](https://www.mentimeter.com/es-ES)
# > 2. Digita el codigo ```6365 1438```
# > 3. Escribe tu nombre y apellido, no emplees apodos o disminutivos porque tu puntuación no será tenida en cuenta.

# %% [markdown]
# ### Obtención del sello

# %% [markdown]
# Escriba lo siguiente en su cuaderno para le sean asignados los puntos obtenidos en el tecno-quiz:

# %% [markdown]
# - Ambito conceptual: El emprendimiento tecnológico : concepto, características y aplicaciones en la vida cotidiana.
# - Competencia 1:
# - Validar los conocimientos previos sobre conceptos relacionados al emprendimiento tecnológico.
