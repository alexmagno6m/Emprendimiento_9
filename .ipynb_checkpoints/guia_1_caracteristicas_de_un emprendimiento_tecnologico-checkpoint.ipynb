# %% [markdown]
# Profesor: __Alexander Acevedo Gomez__<br>
# Ingeniero de Sistemas<br>
# __Magister en Modelado y Simulacion por Computador__<br>
# @Alex6m

# %% [markdown]
# # Guia 1: Emprendimiento tecnológico en nuestro entorno

# %% [markdown]
# Esta guía busca que reconozcas como las aplicaciones y herramientas tecnologicas que empleas a diario iniciaron como un emprendimiento y en la gran mayoria de casos con muy pocos recursos, sin embargo, debido al exito inicial y a un buen manejo financiero crecieron hasta el punto de convertirse en los gigantes tecnologicos que conocemos hoy.

# %% [markdown]
# ### Instrucciones

# %% [markdown]
# > 1. Contesta las preguntas, no es necesario que escribas el enunciado.
# > 2. En la parte final realiza en el cuaderno el diagrama que se muestra.
# > 3. Copia el objetivo, ambito y compentencia para obtener tu sello.

# %% [markdown]
# ## I. Parte 1: Lee con atención y luego contesta las preguntas:

# %% [markdown]
# > _Un emprendimiento tecnológico es una iniciativa que surge cuando una persona o un grupo identifica un problema o necesidad en su entorno y decide buscar una solución utilizando la tecnología como herramienta principal._
# >
# >_A diferencia de los negocios tradicionales, en los emprendimientos tecnológicos la tecnología no es un simple apoyo, sino el elemento central que permite que la idea funcione. Por ejemplo, aplicaciones móviles, plataformas digitales o servicios en línea que conectan personas y facilitan tareas cotidianas._
# >
# > _Estos emprendimientos suelen ser reconocibles porque aprovechan herramientas digitales, buscan innovar y pueden llegar rápidamente a muchas personas gracias al uso de internet._

# %% [markdown]
# 1. Una forma de entender qué es un emprendimeinto tecnológico es cuando:
# 2. Los emprendimientos tecnológicos se diferencian  de los tradicionales porque:
# 3. Los emprendimientos tecnológicos son facilmente reconocibles porque:
# 4. Que emprendimientos tecnologicos empleas a diario?
# 5. Conoces algun emprendimiento tecnologico colombiano, si es asi, cual?

# %% [markdown]
# ## II. Parte 2: Diagrama de emprendimientos tecnológicos

# %% [markdown]
# Realiza el siguiente diagrama en tu cuaderno, cuando lo abras haz clic en `replace my content`.

# %% [markdown]
# __[enlace](https://excalidraw.com/#json=zdSTh2Ul6mm5EUk4Ibgx7,sz-C1ryrqCzIWn1vMWYbJQ)__

# %% [markdown]
# ### Obtención del sello (10 puntos)

# %% [markdown]
# Finalmente copia lo siguiente en tu cuaderno:

# %% [markdown]
# > Competencia: 1
# >
# > Ámbito conceptual: El emprendimiento tecnológico : concepto, características y aplicaciones en la vida cotidiana.
# >
# > Objetivo: comprender las principales características de un emprendimiento tecnológico y reconocerlas dentro del contexto colombiano.
